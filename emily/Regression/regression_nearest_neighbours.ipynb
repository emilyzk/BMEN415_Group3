# %% [markdown]
# #### 1. Import Necessary Packages and Data

# %%
# GENERAL IMPORTS
import pandas as pd                                    #Used to read data
import csv                                             #Used for read data
import numpy as np                                     #Used to compute Root Mean Square Error
import matplotlib.pyplot as plt                        #Used to visualize data
import seaborn as sns                                  #Used to visualize data
from sklearn.model_selection import train_test_split   #Used to split the data into test and train sets 
from sklearn import metrics                            #Used to compute R^2, Mean Abs Error and Mean Square Error  
from sklearn.feature_selection import SelectKBest      #Used to compute the k scores and select features accordingly
from sklearn.feature_selection import f_regression     #Used to test the efficacy of each feature
from scipy.stats import gaussian_kde                   #Used to compute point density

# MODEL SPECIFIC IMPORTS
from sklearn.neighbors import KNeighborsRegressor      #Used to fit and predict a Nearest Neighbours Model 

# DATA IMPORT
inputData = pd.read_excel(r'/Users/emilyknight/Documents/BMEN415 Final Project/Volumetric_features.xlsx', engine='openpyxl') #Import and Shuffle data

inputData.head() #Print complete dataset to console
# Out:
#    S.No  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0     1                 22916.9              982.7
# 1     2                 22953.2              984.5
# 2     3                 23320.4             1062.1
# 3     4                 24360.0             1000.5
# 4     5                 25769.4             1124.4
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus  \
# 0                       15196.7                 55796.4         6855.5
# 1                       15289.7                 55778.6         6835.1
# 2                       15382.1                 55551.2         7566.0
# 3                       14805.4                 54041.8         8004.6
# 4                       16331.1                 54108.6         6677.4
#
#    Left-Caudate  Left-Putamen  Left-Pallidum  3rd-Ventricle  ...  \
# 0        2956.4        4240.7         2223.9         2034.4  ...
# 1        3064.2        4498.6         2354.1         1927.1  ...
# 2        3231.7        4456.2         1995.4         2064.7  ...
# 3        3137.3        4262.2         1983.4         2017.7  ...
# 4        2964.4        4204.6         2409.7         2251.8  ...
#
#    rh_supramarginal_thickness  rh_frontalpole_thickness  \
# 0                       2.408                     2.629
# 1                       2.417                     2.640
# 2                       2.374                     2.601
# 3                       2.366                     2.639
# 4                       2.381                     2.555
#
#    rh_temporalpole_thickness  rh_transversetemporal_thickness  \
# 0                      3.519                            2.009
# 1                      3.488                            2.111
# 2                      3.342                            2.146
# 3                      3.361                            2.056
# 4                      3.450                            2.052
#
#    rh_insula_thickness  rh_MeanThickness_thickness  BrainSegVolNotVent.2  \
# 0                2.825                     2.33635               1093846
# 1                2.720                     2.34202               1099876
# 2                2.684                     2.31982               1097999
# 3                2.700                     2.29215               1070117
# 4                2.574                     2.30397               1075926
#
#         eTIV.1  Age  dataset
# 0  1619602.965   85        1
# 1  1624755.130   85        1
# 2  1622609.518   86        1
# 3  1583854.236   87        1
# 4  1617375.362   89        1
#
# [5 rows x 141 columns]

# %% [markdown]
# #### 2. Determine Data Correlation with the Output Variable

# %%
cor = inputData.corr() #Define correlation 

cor_target = abs(cor["Age"]) #Find correlation with age

relevant_features = cor_target[cor_target>0.6] #Determine relevant features (features with >60% correlation) 

relevant_features.to_frame #Turn the series of relevant features into a dataframe
relevant_features #Print relevant features to console
# Out:
# Left-Thalamus                        0.696598
# 3rd-Ventricle                        0.616427
# Left-Hippocampus                     0.601390
# Left-Amygdala                        0.612836
# Left-choroid-plexus                  0.630961
# Right-Thalamus                       0.677696
# Right-Putamen                        0.620966
# Right-Accumbens-area                 0.658007
# lhCortexVol                          0.657288
# rhCortexVol                          0.656251
# CortexVol                            0.658139
# SubCortGrayVol                       0.676319
# TotalGrayVol                         0.668308
# lh_inferiorparietal_thickness        0.629624
# lh_parsopercularis_thickness         0.640510
# lh_parstriangularis_thickness        0.635172
# lh_postcentral_thickness             0.606031
# lh_precentral_thickness              0.638825
# lh_precuneus_thickness               0.634651
# lh_rostralmiddlefrontal_thickness    0.648759
# lh_superiorfrontal_thickness         0.695692
# lh_superiortemporal_thickness        0.673877
# lh_supramarginal_thickness           0.656548
# lh_MeanThickness_thickness           0.704179
# rh_inferiorparietal_thickness        0.646494
# rh_parsopercularis_thickness         0.652487
# rh_parstriangularis_thickness        0.686229
# rh_postcentral_thickness             0.600376
# rh_precentral_thickness              0.619773
# rh_precuneus_thickness               0.631260
# rh_rostralmiddlefrontal_thickness    0.638059
# rh_superiorfrontal_thickness         0.673897
# rh_superiortemporal_thickness        0.680944
# rh_supramarginal_thickness           0.665053
# rh_MeanThickness_thickness           0.706354
# Age                                  1.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### 3. Create New Dataframe with Relevant Features

# %%
relevant_feature_names = relevant_features.index.values #Create tuple of relevant feature names
relevantData = inputData.filter(relevant_feature_names, axis=1) #Copy relevant features to a new dataframe
relevantData.head() #Print relevant dataset to console
# Out:
#    Left-Thalamus  3rd-Ventricle  Left-Hippocampus  Left-Amygdala  \
# 0         6855.5         2034.4            3443.0         1259.4
# 1         6835.1         1927.1            3479.4         1298.6
# 2         7566.0         2064.7            3385.2         1279.6
# 3         8004.6         2017.7            3311.5         1211.5
# 4         6677.4         2251.8            3220.8         1244.8
#
#    Left-choroid-plexus  Right-Thalamus  Right-Putamen  Right-Accumbens-area  \
# 0                984.1          6420.7         4396.6                 306.9
# 1                966.6          6981.2         4504.1                 336.4
# 2               1020.3          7088.3         4461.0                 306.4
# 3                901.9          7687.1         3979.8                 271.1
# 4               1089.0          7153.5         4353.2                 320.8
#
#    lhCortexVol  rhCortexVol  ...  rh_parstriangularis_thickness  \
# 0  211232.5198  208279.9625  ...                          2.404
# 1  213515.0486  210166.6207  ...                          2.431
# 2  212234.1905  208749.3851  ...                          2.455
# 3  203358.7451  203130.7953  ...                          2.347
# 4  207834.7973  204297.4942  ...                          2.318
#
#    rh_postcentral_thickness  rh_precentral_thickness  rh_precuneus_thickness  \
# 0                     1.872                    2.445                   2.328
# 1                     1.937                    2.503                   2.343
# 2                     1.904                    2.405                   2.310
# 3                     1.866                    2.375                   2.257
# 4                     1.891                    2.419                   2.351
#
#    rh_rostralmiddlefrontal_thickness  rh_superiorfrontal_thickness  \
# 0                              2.147                         2.597
# 1                              2.196                         2.597
# 2                              2.176                         2.607
# 3                              2.144                         2.507
# 4                              2.079                         2.478
#
#    rh_superiortemporal_thickness  rh_supramarginal_thickness  \
# 0                          2.648                       2.408
# 1                          2.660                       2.417
# 2                          2.597                       2.374
# 3                          2.604                       2.366
# 4                          2.597                       2.381
#
#    rh_MeanThickness_thickness  Age
# 0                     2.33635   85
# 1                     2.34202   85
# 2                     2.31982   86
# 3                     2.29215   87
# 4                     2.30397   89
#
# [5 rows x 36 columns]

# %% [markdown]
# #### 4. Select and Split Input and Output Vectors

# %%
# Select Input Vector, X, and Output Vector, y
X = relevantData.drop(columns= ['Age']) #Input vector is the brain volume
y = relevantData['Age'] #Output data is the age

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) #Split vectors, 20% will be used for testing

# %% [markdown]
# #### 5. Graph Feature Scores for the Input and Output Vectors

# %%
def select_features(X_train, y_train, X_test): #Function used to select applicable features
    fs = SelectKBest(score_func=f_regression, k='all') #Configure to Select All Features
    fs.fit(X_train, y_train)  #Learn the relationship from training data
    X_train_fs = fs.transform(X_train) #Transform the input training data
    X_test_fs = fs.transform(X_test) #Transform the input test data
    return X_train_fs, X_test_fs, fs
 
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test) #Select applicable features

for i in range(len(fs.scores_)): #For each of the feature scores
    print('Feature %d: %f' % (i, fs.scores_[i])) #Print the score to the console

    
plt.bar([i for i in range(len(fs.scores_))], fs.scores_) #Plot the scores where a longer bar represents a more applicable feature
plt.show()
# Out:
# Feature 0: 3159.689256
# Feature 1: 2089.042612
# Feature 2: 1919.654499
# Feature 3: 1948.180468
# Feature 4: 2096.455700
# Feature 5: 2840.068168
# Feature 6: 2051.208862
# Feature 7: 2539.192073
# Feature 8: 2577.952724
# Feature 9: 2544.913214
# Feature 10: 2578.612253
# Feature 11: 2806.570091
# Feature 12: 2705.000986
# Feature 13: 2186.721467
# Feature 14: 2275.268281
# Feature 15: 2269.129060
# Feature 16: 1942.605770
# Feature 17: 2292.728480
# Feature 18: 2229.941388
# Feature 19: 2381.530658
# Feature 20: 3014.330742
# Feature 21: 2770.067602
# Feature 22: 2482.451509
# Feature 23: 3256.648460
# Feature 24: 2347.346460
# Feature 25: 2396.658764
# Feature 26: 2898.416902
# Feature 27: 1854.443761
# Feature 28: 2077.308134
# Feature 29: 2148.947644
# Feature 30: 2228.375385
# Feature 31: 2728.822999
# Feature 32: 2869.991662
# Feature 33: 2545.885478
# Feature 34: 3274.089007

# %% [markdown]
# #### 6. Determine the Best Features

# %%
k = 10    #Obtaining the 10 best features

indices = np.argsort(fs.scores_)[::-1] #Sort the features
print(indices) #Print the features from best to worst

relevantData.corr()#Print the feature correlation
# Out:
# [34 23  0 20 26 32  5 11 21 31 12 10  8 33  9  7 22 25 19 24 17 14 15 18
#  30 13 29  4  1 28  6  3 16  2 27]
#                                    Left-Thalamus  3rd-Ventricle  \
# Left-Thalamus                           1.000000      -0.406120
# 3rd-Ventricle                          -0.406120       1.000000
# Left-Hippocampus                        0.742072      -0.331450
# Left-Amygdala                           0.677330      -0.336555
# Left-choroid-plexus                    -0.438474       0.710784
# Right-Thalamus                          0.909240      -0.358931
# Right-Putamen                           0.672992      -0.282654
# Right-Accumbens-area                    0.560422      -0.433445
# lhCortexVol                             0.739606      -0.251124
# rhCortexVol                             0.736062      -0.249049
# CortexVol                               0.739370      -0.250606
# SubCortGrayVol                          0.881774      -0.301913
# TotalGrayVol                            0.778010      -0.251665
# lh_inferiorparietal_thickness           0.489534      -0.464407
# lh_parsopercularis_thickness            0.488550      -0.446368
# lh_parstriangularis_thickness           0.465400      -0.450671
# lh_postcentral_thickness                0.477192      -0.442396
# lh_precentral_thickness                 0.454323      -0.452943
# lh_precuneus_thickness                  0.507426      -0.428836
# lh_rostralmiddlefrontal_thickness       0.495763      -0.503038
# lh_superiorfrontal_thickness            0.484359      -0.513996
# lh_superiortemporal_thickness           0.533600      -0.488566
# lh_supramarginal_thickness              0.488999      -0.503946
# lh_MeanThickness_thickness              0.523219      -0.500323
# rh_inferiorparietal_thickness           0.500260      -0.491205
# rh_parsopercularis_thickness            0.495569      -0.435916
# rh_parstriangularis_thickness           0.498658      -0.510964
# rh_postcentral_thickness                0.470322      -0.423329
# rh_precentral_thickness                 0.421876      -0.452654
# rh_precuneus_thickness                  0.474832      -0.431980
# rh_rostralmiddlefrontal_thickness       0.460434      -0.503078
# rh_superiorfrontal_thickness            0.470515      -0.518317
# rh_superiortemporal_thickness           0.548083      -0.496620
# rh_supramarginal_thickness              0.508498      -0.493954
# rh_MeanThickness_thickness              0.520636      -0.507112
# Age                                    -0.696598       0.616427
#
#                                    Left-Hippocampus  Left-Amygdala  \
# Left-Thalamus                              0.742072       0.677330
# 3rd-Ventricle                             -0.331450      -0.336555
# Left-Hippocampus                           1.000000       0.782702
# Left-Amygdala                              0.782702       1.000000
# Left-choroid-plexus                       -0.368454      -0.354736
# Right-Thalamus                             0.734812       0.711494
# Right-Putamen                              0.636997       0.644764
# Right-Accumbens-area                       0.593081       0.611783
# lhCortexVol                                0.697834       0.695496
# rhCortexVol                                0.696184       0.695223
# CortexVol                                  0.698462       0.696811
# SubCortGrayVol                             0.837463       0.790164
# TotalGrayVol                               0.731838       0.715109
# lh_inferiorparietal_thickness              0.450638       0.480665
# lh_parsopercularis_thickness               0.446796       0.452450
# lh_parstriangularis_thickness              0.430141       0.426612
# lh_postcentral_thickness                   0.461528       0.469939
# lh_precentral_thickness                    0.465694       0.496954
# lh_precuneus_thickness                     0.460151       0.498429
# lh_rostralmiddlefrontal_thickness          0.458785       0.466387
# lh_superiorfrontal_thickness               0.450550       0.473490
# lh_superiortemporal_thickness              0.544857       0.543073
# lh_supramarginal_thickness                 0.462623       0.469331
# lh_MeanThickness_thickness                 0.512800       0.535854
# rh_inferiorparietal_thickness              0.447970       0.480708
# rh_parsopercularis_thickness               0.460208       0.493964
# rh_parstriangularis_thickness              0.437268       0.451708
# rh_postcentral_thickness                   0.463632       0.474580
# rh_precentral_thickness                    0.417402       0.458792
# rh_precuneus_thickness                     0.449612       0.485099
# rh_rostralmiddlefrontal_thickness          0.438606       0.450822
# rh_superiorfrontal_thickness               0.430650       0.457801
# rh_superiortemporal_thickness              0.561939       0.556465
# rh_supramarginal_thickness                 0.471767       0.496701
# rh_MeanThickness_thickness                 0.509885       0.535964
# Age                                       -0.601390      -0.612836
#
#                                    Left-choroid-plexus  Right-Thalamus  \
# Left-Thalamus                                -0.438474        0.909240
# 3rd-Ventricle                                 0.710784       -0.358931
# Left-Hippocampus                             -0.368454        0.734812
# Left-Amygdala                                -0.354736        0.711494
# Left-choroid-plexus                           1.000000       -0.380079
# Right-Thalamus                               -0.380079        1.000000
# Right-Putamen                                -0.312257        0.673963
# Right-Accumbens-area                         -0.424564        0.548648
# lhCortexVol                                  -0.261279        0.766735
# rhCortexVol                                  -0.259709        0.772401
# CortexVol                                    -0.261036        0.771182
# SubCortGrayVol                               -0.334388        0.886226
# TotalGrayVol                                 -0.264588        0.804133
# lh_inferiorparietal_thickness                -0.480773        0.529015
# lh_parsopercularis_thickness                 -0.440193        0.518025
# lh_parstriangularis_thickness                -0.439230        0.479107
# lh_postcentral_thickness                     -0.445800        0.518585
# lh_precentral_thickness                      -0.451902        0.514724
# lh_precuneus_thickness                       -0.462104        0.547522
# lh_rostralmiddlefrontal_thickness            -0.483221        0.526142
# lh_superiorfrontal_thickness                 -0.528447        0.515583
# lh_superiortemporal_thickness                -0.488963        0.556667
# lh_supramarginal_thickness                   -0.504254        0.519930
# lh_MeanThickness_thickness                   -0.512371        0.571616
# rh_inferiorparietal_thickness                -0.501668        0.547809
# rh_parsopercularis_thickness                 -0.424357        0.532313
# rh_parstriangularis_thickness                -0.492985        0.505537
# rh_postcentral_thickness                     -0.437481        0.522971
# rh_precentral_thickness                      -0.445470        0.475090
# rh_precuneus_thickness                       -0.468587        0.532949
# rh_rostralmiddlefrontal_thickness            -0.478938        0.496320
# rh_superiorfrontal_thickness                 -0.516429        0.499253
# rh_superiortemporal_thickness                -0.503019        0.576496
# rh_supramarginal_thickness                   -0.503942        0.550517
# rh_MeanThickness_thickness                   -0.514694        0.579179
# Age                                           0.630961       -0.677696
#
#                                    Right-Putamen  Right-Accumbens-area  \
# Left-Thalamus                           0.672992              0.560422
# 3rd-Ventricle                          -0.282654             -0.433445
# Left-Hippocampus                        0.636997              0.593081
# Left-Amygdala                           0.644764              0.611783
# Left-choroid-plexus                    -0.312257             -0.424564
# Right-Thalamus                          0.673963              0.548648
# Right-Putamen                           1.000000              0.668210
# Right-Accumbens-area                    0.668210              1.000000
# lhCortexVol                             0.719127              0.629430
# rhCortexVol                             0.718742              0.633977
# CortexVol                               0.720435              0.633028
# SubCortGrayVol                          0.859560              0.700131
# TotalGrayVol                            0.738272              0.642621
# lh_inferiorparietal_thickness           0.467198              0.455633
# lh_parsopercularis_thickness            0.460815              0.453695
# lh_parstriangularis_thickness           0.446376              0.435830
# lh_postcentral_thickness                0.464014              0.447406
# lh_precentral_thickness                 0.481937              0.497873
# lh_precuneus_thickness                  0.502938              0.474306
# lh_rostralmiddlefrontal_thickness       0.446669              0.444456
# lh_superiorfrontal_thickness            0.478415              0.453731
# lh_superiortemporal_thickness           0.504866              0.502696
# lh_supramarginal_thickness              0.460434              0.455656
# lh_MeanThickness_thickness              0.526974              0.519930
# rh_inferiorparietal_thickness           0.463887              0.457280
# rh_parsopercularis_thickness            0.479452              0.467304
# rh_parstriangularis_thickness           0.466129              0.478364
# rh_postcentral_thickness                0.444167              0.448640
# rh_precentral_thickness                 0.453377              0.477793
# rh_precuneus_thickness                  0.478762              0.465009
# rh_rostralmiddlefrontal_thickness       0.426866              0.431929
# rh_superiorfrontal_thickness            0.463423              0.427612
# rh_superiortemporal_thickness           0.503343              0.497467
# rh_supramarginal_thickness              0.482041              0.486130
# rh_MeanThickness_thickness              0.523153              0.519841
# Age                                    -0.620966             -0.658007
#
#                                    lhCortexVol  rhCortexVol  ...  \
# Left-Thalamus                         0.739606     0.736062  ...
# 3rd-Ventricle                        -0.251124    -0.249049  ...
# Left-Hippocampus                      0.697834     0.696184  ...
# Left-Amygdala                         0.695496     0.695223  ...
# Left-choroid-plexus                  -0.261279    -0.259709  ...
# Right-Thalamus                        0.766735     0.772401  ...
# Right-Putamen                         0.719127     0.718742  ...
# Right-Accumbens-area                  0.629430     0.633977  ...
# lhCortexVol                           1.000000     0.991674  ...
# rhCortexVol                           0.991674     1.000000  ...
# CortexVol                             0.997906     0.997927  ...
# SubCortGrayVol                        0.830768     0.831214  ...
# TotalGrayVol                          0.987315     0.987635  ...
# lh_inferiorparietal_thickness         0.592956     0.585208  ...
# lh_parsopercularis_thickness          0.607182     0.599119  ...
# lh_parstriangularis_thickness         0.551666     0.546138  ...
# lh_postcentral_thickness              0.594280     0.583694  ...
# lh_precentral_thickness               0.605907     0.599728  ...
# lh_precuneus_thickness                0.629841     0.622916  ...
# lh_rostralmiddlefrontal_thickness     0.578651     0.570995  ...
# lh_superiorfrontal_thickness          0.563286     0.560324  ...
# lh_superiortemporal_thickness         0.625434     0.618777  ...
# lh_supramarginal_thickness            0.586546     0.577048  ...
# lh_MeanThickness_thickness            0.671106     0.662992  ...
# rh_inferiorparietal_thickness         0.593946     0.603918  ...
# rh_parsopercularis_thickness          0.606405     0.609631  ...
# rh_parstriangularis_thickness         0.561880     0.564357  ...
# rh_postcentral_thickness              0.592039     0.596521  ...
# rh_precentral_thickness               0.561944     0.566115  ...
# rh_precuneus_thickness                0.614467     0.614431  ...
# rh_rostralmiddlefrontal_thickness     0.525942     0.530821  ...
# rh_superiorfrontal_thickness          0.531112     0.528925  ...
# rh_superiortemporal_thickness         0.610499     0.618048  ...
# rh_supramarginal_thickness            0.606066     0.616361  ...
# rh_MeanThickness_thickness            0.659920     0.667252  ...
# Age                                  -0.657288    -0.656251  ...
#
#                                    rh_parstriangularis_thickness  \
# Left-Thalamus                                           0.498658
# 3rd-Ventricle                                          -0.510964
# Left-Hippocampus                                        0.437268
# Left-Amygdala                                           0.451708
# Left-choroid-plexus                                    -0.492985
# Right-Thalamus                                          0.505537
# Right-Putamen                                           0.466129
# Right-Accumbens-area                                    0.478364
# lhCortexVol                                             0.561880
# rhCortexVol                                             0.564357
# CortexVol                                               0.564297
# SubCortGrayVol                                          0.499665
# TotalGrayVol                                            0.555691
# lh_inferiorparietal_thickness                           0.716010
# lh_parsopercularis_thickness                            0.762642
# lh_parstriangularis_thickness                           0.786525
# lh_postcentral_thickness                                0.680876
# lh_precentral_thickness                                 0.706656
# lh_precuneus_thickness                                  0.703962
# lh_rostralmiddlefrontal_thickness                       0.777858
# lh_superiorfrontal_thickness                            0.778673
# lh_superiortemporal_thickness                           0.712518
# lh_supramarginal_thickness                              0.755972
# lh_MeanThickness_thickness                              0.812049
# rh_inferiorparietal_thickness                           0.730396
# rh_parsopercularis_thickness                            0.780829
# rh_parstriangularis_thickness                           1.000000
# rh_postcentral_thickness                                0.682205
# rh_precentral_thickness                                 0.699766
# rh_precuneus_thickness                                  0.710177
# rh_rostralmiddlefrontal_thickness                       0.800868
# rh_superiorfrontal_thickness                            0.765817
# rh_superiortemporal_thickness                           0.724859
# rh_supramarginal_thickness                              0.764095
# rh_MeanThickness_thickness                              0.826256
# Age                                                    -0.686229
#
#                                    rh_postcentral_thickness  \
# Left-Thalamus                                      0.470322
# 3rd-Ventricle                                     -0.423329
# Left-Hippocampus                                   0.463632
# Left-Amygdala                                      0.474580
# Left-choroid-plexus                               -0.437481
# Right-Thalamus                                     0.522971
# Right-Putamen                                      0.444167
# Right-Accumbens-area                               0.448640
# lhCortexVol                                        0.592039
# rhCortexVol                                        0.596521
# CortexVol                                          0.595526
# SubCortGrayVol                                     0.496168
# TotalGrayVol                                       0.579592
# lh_inferiorparietal_thickness                      0.741114
# lh_parsopercularis_thickness                       0.660290
# lh_parstriangularis_thickness                      0.667717
# lh_postcentral_thickness                           0.866645
# lh_precentral_thickness                            0.734404
# lh_precuneus_thickness                             0.745273
# lh_rostralmiddlefrontal_thickness                  0.706330
# lh_superiorfrontal_thickness                       0.700990
# lh_superiortemporal_thickness                      0.673101
# lh_supramarginal_thickness                         0.755520
# lh_MeanThickness_thickness                         0.811636
# rh_inferiorparietal_thickness                      0.767338
# rh_parsopercularis_thickness                       0.667700
# rh_parstriangularis_thickness                      0.682205
# rh_postcentral_thickness                           1.000000
# rh_precentral_thickness                            0.672591
# rh_precuneus_thickness                             0.765870
# rh_rostralmiddlefrontal_thickness                  0.691626
# rh_superiorfrontal_thickness                       0.675118
# rh_superiortemporal_thickness                      0.686330
# rh_supramarginal_thickness                         0.779958
# rh_MeanThickness_thickness                         0.829619
# Age                                               -0.600376
#
#                                    rh_precentral_thickness  \
# Left-Thalamus                                     0.421876
# 3rd-Ventricle                                    -0.452654
# Left-Hippocampus                                  0.417402
# Left-Amygdala                                     0.458792
# Left-choroid-plexus                              -0.445470
# Right-Thalamus                                    0.475090
# Right-Putamen                                     0.453377
# Right-Accumbens-area                              0.477793
# lhCortexVol                                       0.561944
# rhCortexVol                                       0.566115
# CortexVol                                         0.565212
# SubCortGrayVol                                    0.474421
# TotalGrayVol                                      0.549536
# lh_inferiorparietal_thickness                     0.742536
# lh_parsopercularis_thickness                      0.698128
# lh_parstriangularis_thickness                     0.677552
# lh_postcentral_thickness                          0.720862
# lh_precentral_thickness                           0.883141
# lh_precuneus_thickness                            0.753238
# lh_rostralmiddlefrontal_thickness                 0.712136
# lh_superiorfrontal_thickness                      0.773282
# lh_superiortemporal_thickness                     0.686747
# lh_supramarginal_thickness                        0.755374
# lh_MeanThickness_thickness                        0.844125
# rh_inferiorparietal_thickness                     0.759188
# rh_parsopercularis_thickness                      0.719990
# rh_parstriangularis_thickness                     0.699766
# rh_postcentral_thickness                          0.672591
# rh_precentral_thickness                           1.000000
# rh_precuneus_thickness                            0.747756
# rh_rostralmiddlefrontal_thickness                 0.701087
# rh_superiorfrontal_thickness                      0.759535
# rh_superiortemporal_thickness                     0.680737
# rh_supramarginal_thickness                        0.784639
# rh_MeanThickness_thickness                        0.855929
# Age                                              -0.619773
#
#                                    rh_precuneus_thickness  \
# Left-Thalamus                                    0.474832
# 3rd-Ventricle                                   -0.431980
# Left-Hippocampus                                 0.449612
# Left-Amygdala                                    0.485099
# Left-choroid-plexus                             -0.468587
# Right-Thalamus                                   0.532949
# Right-Putamen                                    0.478762
# Right-Accumbens-area                             0.465009
# lhCortexVol                                      0.614467
# rhCortexVol                                      0.614431
# CortexVol                                        0.615732
# SubCortGrayVol                                   0.513822
# TotalGrayVol                                     0.600430
# lh_inferiorparietal_thickness                    0.847777
# lh_parsopercularis_thickness                     0.703239
# lh_parstriangularis_thickness                    0.701036
# lh_postcentral_thickness                         0.776415
# lh_precentral_thickness                          0.776973
# lh_precuneus_thickness                           0.906156
# lh_rostralmiddlefrontal_thickness                0.758614
# lh_superiorfrontal_thickness                     0.785060
# lh_superiortemporal_thickness                    0.710040
# lh_supramarginal_thickness                       0.801537
# lh_MeanThickness_thickness                       0.889552
# rh_inferiorparietal_thickness                    0.846521
# rh_parsopercularis_thickness                     0.706894
# rh_parstriangularis_thickness                    0.710177
# rh_postcentral_thickness                         0.765870
# rh_precentral_thickness                          0.747756
# rh_precuneus_thickness                           1.000000
# rh_rostralmiddlefrontal_thickness                0.729683
# rh_superiorfrontal_thickness                     0.775046
# rh_superiortemporal_thickness                    0.697602
# rh_supramarginal_thickness                       0.808293
# rh_MeanThickness_thickness                       0.898756
# Age                                             -0.631260
#
#                                    rh_rostralmiddlefrontal_thickness  \
# Left-Thalamus                                               0.460434
# 3rd-Ventricle                                              -0.503078
# Left-Hippocampus                                            0.438606
# Left-Amygdala                                               0.450822
# Left-choroid-plexus                                        -0.478938
# Right-Thalamus                                              0.496320
# Right-Putamen                                               0.426866
# Right-Accumbens-area                                        0.431929
# lhCortexVol                                                 0.525942
# rhCortexVol                                                 0.530821
# CortexVol                                                   0.529491
# SubCortGrayVol                                              0.463659
# TotalGrayVol                                                0.518891
# lh_inferiorparietal_thickness                               0.746679
# lh_parsopercularis_thickness                                0.736868
# lh_parstriangularis_thickness                               0.752499
# lh_postcentral_thickness                                    0.690467
# lh_precentral_thickness                                     0.717537
# lh_precuneus_thickness                                      0.725957
# lh_rostralmiddlefrontal_thickness                           0.885757
# lh_superiorfrontal_thickness                                0.843590
# lh_superiortemporal_thickness                               0.686988
# lh_supramarginal_thickness                                  0.760713
# lh_MeanThickness_thickness                                  0.839641
# rh_inferiorparietal_thickness                               0.752391
# rh_parsopercularis_thickness                                0.757307
# rh_parstriangularis_thickness                               0.800868
# rh_postcentral_thickness                                    0.691626
# rh_precentral_thickness                                     0.701087
# rh_precuneus_thickness                                      0.729683
# rh_rostralmiddlefrontal_thickness                           1.000000
# rh_superiorfrontal_thickness                                0.843804
# rh_superiortemporal_thickness                               0.697143
# rh_supramarginal_thickness                                  0.762384
# rh_MeanThickness_thickness                                  0.861382
# Age                                                        -0.638059
#
#                                    rh_superiorfrontal_thickness  \
# Left-Thalamus                                          0.470515
# 3rd-Ventricle                                         -0.518317
# Left-Hippocampus                                       0.430650
# Left-Amygdala                                          0.457801
# Left-choroid-plexus                                   -0.516429
# Right-Thalamus                                         0.499253
# Right-Putamen                                          0.463423
# Right-Accumbens-area                                   0.427612
# lhCortexVol                                            0.531112
# rhCortexVol                                            0.528925
# CortexVol                                              0.531122
# SubCortGrayVol                                         0.473950
# TotalGrayVol                                           0.519476
# lh_inferiorparietal_thickness                          0.785955
# lh_parsopercularis_thickness                           0.746134
# lh_parstriangularis_thickness                          0.747209
# lh_postcentral_thickness                               0.709832
# lh_precentral_thickness                                0.772947
# lh_precuneus_thickness                                 0.780881
# lh_rostralmiddlefrontal_thickness                      0.831811
# lh_superiorfrontal_thickness                           0.938783
# lh_superiortemporal_thickness                          0.716252
# lh_supramarginal_thickness                             0.800336
# lh_MeanThickness_thickness                             0.869494
# rh_inferiorparietal_thickness                          0.770357
# rh_parsopercularis_thickness                           0.753308
# rh_parstriangularis_thickness                          0.765817
# rh_postcentral_thickness                               0.675118
# rh_precentral_thickness                                0.759535
# rh_precuneus_thickness                                 0.775046
# rh_rostralmiddlefrontal_thickness                      0.843804
# rh_superiorfrontal_thickness                           1.000000
# rh_superiortemporal_thickness                          0.709820
# rh_supramarginal_thickness                             0.767538
# rh_MeanThickness_thickness                             0.875757
# Age                                                   -0.673897
#
#                                    rh_superiortemporal_thickness  \
# Left-Thalamus                                           0.548083
# 3rd-Ventricle                                          -0.496620
# Left-Hippocampus                                        0.561939
# Left-Amygdala                                           0.556465
# Left-choroid-plexus                                    -0.503019
# Right-Thalamus                                          0.576496
# Right-Putamen                                           0.503343
# Right-Accumbens-area                                    0.497467
# lhCortexVol                                             0.610499
# rhCortexVol                                             0.618048
# CortexVol                                               0.615566
# SubCortGrayVol                                          0.569248
# TotalGrayVol                                            0.615517
# lh_inferiorparietal_thickness                           0.694861
# lh_parsopercularis_thickness                            0.725725
# lh_parstriangularis_thickness                           0.694712
# lh_postcentral_thickness                                0.687915
# lh_precentral_thickness                                 0.692452
# lh_precuneus_thickness                                  0.700362
# lh_rostralmiddlefrontal_thickness                       0.708728
# lh_superiorfrontal_thickness                            0.718369
# lh_superiortemporal_thickness                           0.872223
# lh_supramarginal_thickness                              0.764948
# lh_MeanThickness_thickness                              0.817817
# rh_inferiorparietal_thickness                           0.731350
# rh_parsopercularis_thickness                            0.730593
# rh_parstriangularis_thickness                           0.724859
# rh_postcentral_thickness                                0.686330
# rh_precentral_thickness                                 0.680737
# rh_precuneus_thickness                                  0.697602
# rh_rostralmiddlefrontal_thickness                       0.697143
# rh_superiorfrontal_thickness                            0.709820
# rh_superiortemporal_thickness                           1.000000
# rh_supramarginal_thickness                              0.792113
# rh_MeanThickness_thickness                              0.838040
# Age                                                    -0.680944
#
#                                    rh_supramarginal_thickness  \
# Left-Thalamus                                        0.508498
# 3rd-Ventricle                                       -0.493954
# Left-Hippocampus                                     0.471767
# Left-Amygdala                                        0.496701
# Left-choroid-plexus                                 -0.503942
# Right-Thalamus                                       0.550517
# Right-Putamen                                        0.482041
# Right-Accumbens-area                                 0.486130
# lhCortexVol                                          0.606066
# rhCortexVol                                          0.616361
# CortexVol                                            0.612503
# SubCortGrayVol                                       0.525786
# TotalGrayVol                                         0.601863
# lh_inferiorparietal_thickness                        0.811855
# lh_parsopercularis_thickness                         0.750449
# lh_parstriangularis_thickness                        0.732542
# lh_postcentral_thickness                             0.765985
# lh_precentral_thickness                              0.781422
# lh_precuneus_thickness                               0.803284
# lh_rostralmiddlefrontal_thickness                    0.777600
# lh_superiorfrontal_thickness                         0.787261
# lh_superiortemporal_thickness                        0.770995
# lh_supramarginal_thickness                           0.847888
# lh_MeanThickness_thickness                           0.880098
# rh_inferiorparietal_thickness                        0.866662
# rh_parsopercularis_thickness                         0.762959
# rh_parstriangularis_thickness                        0.764095
# rh_postcentral_thickness                             0.779958
# rh_precentral_thickness                              0.784639
# rh_precuneus_thickness                               0.808293
# rh_rostralmiddlefrontal_thickness                    0.762384
# rh_superiorfrontal_thickness                         0.767538
# rh_superiortemporal_thickness                        0.792113
# rh_supramarginal_thickness                           1.000000
# rh_MeanThickness_thickness                           0.907426
# Age                                                 -0.665053
#
#                                    rh_MeanThickness_thickness       Age
# Left-Thalamus                                        0.520636 -0.696598
# 3rd-Ventricle                                       -0.507112  0.616427
# Left-Hippocampus                                     0.509885 -0.601390
# Left-Amygdala                                        0.535964 -0.612836
# Left-choroid-plexus                                 -0.514694  0.630961
# Right-Thalamus                                       0.579179 -0.677696
# Right-Putamen                                        0.523153 -0.620966
# Right-Accumbens-area                                 0.519841 -0.658007
# lhCortexVol                                          0.659920 -0.657288
# rhCortexVol                                          0.667252 -0.656251
# CortexVol                                            0.664981 -0.658139
# SubCortGrayVol                                       0.558570 -0.676319
# TotalGrayVol                                         0.649071 -0.668308
# lh_inferiorparietal_thickness                        0.881580 -0.629624
# lh_parsopercularis_thickness                         0.811663 -0.640510
# lh_parstriangularis_thickness                        0.799271 -0.635172
# lh_postcentral_thickness                             0.829971 -0.606031
# lh_precentral_thickness                              0.863307 -0.638825
# lh_precuneus_thickness                               0.890444 -0.634651
# lh_rostralmiddlefrontal_thickness                    0.863995 -0.648759
# lh_superiorfrontal_thickness                         0.884679 -0.695692
# lh_superiortemporal_thickness                        0.823986 -0.673877
# lh_supramarginal_thickness                           0.881208 -0.656548
# lh_MeanThickness_thickness                           0.978467 -0.704179
# rh_inferiorparietal_thickness                        0.908234 -0.646494
# rh_parsopercularis_thickness                         0.827984 -0.652487
# rh_parstriangularis_thickness                        0.826256 -0.686229
# rh_postcentral_thickness                             0.829619 -0.600376
# rh_precentral_thickness                              0.855929 -0.619773
# rh_precuneus_thickness                               0.898756 -0.631260
# rh_rostralmiddlefrontal_thickness                    0.861382 -0.638059
# rh_superiorfrontal_thickness                         0.875757 -0.673897
# rh_superiortemporal_thickness                        0.838040 -0.680944
# rh_supramarginal_thickness                           0.907426 -0.665053
# rh_MeanThickness_thickness                           1.000000 -0.706354
# Age                                                 -0.706354  1.000000
#
# [36 rows x 36 columns]

# %% [markdown]
# #### 7. Instantiate and Fit Models

# %%
k_neighbours = KNeighborsRegressor(n_neighbors=4) #K-Neighbours Model with 4 Neighbours

k_neighbours.fit(X_train, y_train) #Fit the Model given 4 Neighbours
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %% [markdown]
# #### 8. Test and Quantify Model Performance

# %%
k_neighbours_predictions = nearest_neighbours_kernel.predict(X_test) #Create predictions based on the KN Model with unseen test data 

#Compare the predictions to the known test values
print('\033[1m' + 'Nearest Neighbours' + '\033[0m')
print('r^2 Value:', metrics.r2_score(y_test, k_neighbours_predictions))
print('Mean Absolute Error (Years):', metrics.mean_absolute_error(y_test, k_neighbours_predictions))
print('Mean Square Error:', metrics.mean_squared_error(y_test, k_neighbours_predictions))
print('Root Mean Sqaure Error (Years):', np.sqrt(metrics.mean_squared_error(y_test, k_neighbours_predictions)))
# Out:
# Nearest Neighbours
# r^2 Value: 0.45591677553202303
# Mean Absolute Error (Years): 11.601654846335697
# Mean Square Error: 232.33747044917257
# Root Mean Sqaure Error (Years): 15.242620196317056

# %% [markdown]
# #### 9. Visualize Data

# %%
sns.scatterplot(y_test, k_neighbours_predictions) #Create a scatter plot of the data 

xy = np.vstack([y_test, k_neighbours_predictions]) #Stack arrays
z = gaussian_kde(xy)(xy) #Calculate point density estimates using Gaussian kernels.

fig,ax = plt.subplots()
ax.scatter(y_test, k_neighbours_predictions, c=z, s=100) #Create a density scatter plot of the data 
plt.show()
# Out:
# /Users/emilyknight/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
